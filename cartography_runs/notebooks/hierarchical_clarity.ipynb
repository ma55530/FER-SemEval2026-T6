# %% [markdown]
# # **Installing the necessary libraries**

# %%
pip -q install scikit-learn torch pandas datasets transformers torchvision accelerate

# %%
import pandas as pd
from datasets import Dataset, load_dataset
import os
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from transformers import AutoModelForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments

# %% [markdown]
# # **Loading the data**

# %%
print("Loading dataset...")
df = load_dataset("ailsntua/QEvasion")

def clarity_to_label(row):
    mapping = {
        "Clear Reply": 0,
        "Ambivalent": 1,
        "Clear Non-Reply": 2
    }
    row["label"] = mapping[row["clarity_label"]]

    # --- FIXED SHORT/LONG BINARY LABEL ---
    # This line was incorrect: row["binary_label"] = 0 if (row["clarity_label"] == 0 or row["clarity_label"] == 1) else 1
    # It should compare with the assigned integer label:
    row["binary_label"] = 0 if (row["label"] == 0 or row["label"] == 1) else 1
    return row

df = df.map(clarity_to_label)
y_test = df["test"]["label"]

# %% [markdown]
# # **Defining the evaluation**

# %%
def evaluate(y_true, y_pred):
    print(classification_report(y_true, y_pred))
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred)
    plt.show()

def compute_metrics_binary(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    return {
        "precision": precision_score(labels, preds, average='macro', zero_division=0),
        "recall": recall_score(labels, preds, average='macro', zero_division=0),
        "f1": f1_score(labels, preds, average='macro', zero_division=0)
    }

def compute_metrics_fine(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    return {
        "precision": precision_score(labels, preds, average='macro', zero_division=0),
        "recall": recall_score(labels, preds, average='macro', zero_division=0),
        "f1": f1_score(labels, preds, average='macro', zero_division=0)
    }

# %% [markdown]
# # **Loading the model and tokenizer**

# %%
binary_model = AutoModelForSequenceClassification.from_pretrained(
    "FacebookAI/roberta-base", num_labels=2
)

fine_model = AutoModelForSequenceClassification.from_pretrained(
    "FacebookAI/roberta-base", num_labels=2
)

tokenizer = AutoTokenizer.from_pretrained("FacebookAI/roberta-base")

def tokenize(example):
    encoded = tokenizer(
        "Question: " + example["interview_question"] +
        " Answer: " + example["interview_answer"],
        padding="max_length",
        max_length=512,
        truncation=True
    )
    encoded["label"] = example["label"]
    encoded["binary_label"] = example["binary_label"]
    return encoded

tokenized_train = df["train"].map(tokenize)
tokenized_test = df["test"].map(tokenize)

cols_to_remove = ["interview_question", "interview_answer", "clarity_label"]

tokenized_train = tokenized_train.remove_columns(cols_to_remove)
tokenized_test  = tokenized_test.remove_columns(cols_to_remove)

tokenized_train.set_format("torch")
tokenized_test.set_format("torch")

# %% [markdown]
# # **Preparing the data for training**

# %%
binary_train = tokenized_train.remove_columns(["label"]).rename_column("binary_label", "labels")
binary_test  = tokenized_test.remove_columns(["label"]).rename_column("binary_label", "labels")

train_fine = tokenized_train.filter(lambda x: x["binary_label"].item() == 0 and x["label"].item() in [0,1]).remove_columns(["binary_label"])
test_fine  = tokenized_test.filter(lambda x: x["binary_label"].item() == 0 and x["label"].item() in [0,1]).remove_columns(["binary_label"])

train_fine = train_fine.rename_column("label", "labels")
test_fine  = test_fine.rename_column("label", "labels")




labels_np = np.array(df["train"]["label"])
class_weights_np = compute_class_weight("balanced", classes=np.unique(labels_np), y=labels_np)
class_weights = torch.tensor(class_weights_np, dtype=torch.float)
print("Class weights:", class_weights)

print(set(train_fine["labels"]))

# %% [markdown]
# # **Defining the evaluation function and training**

# %%
os.environ["WANDB_DISABLED"] = "true"

class WeightedTrainer(Trainer):
    def __init__(self, weights=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.weights = weights

    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs["labels"]
        outputs = model(**inputs)
        logits = outputs.logits

        loss_fct = torch.nn.CrossEntropyLoss(weight=self.weights.to(model.device))
        loss = loss_fct(logits, labels)

        return (loss, outputs) if return_outputs else loss



trainer_binary = WeightedTrainer(
    weights=torch.tensor([1.0, 1.0]),
    model=binary_model,
    train_dataset=binary_train,
    eval_dataset=binary_test,
    compute_metrics=compute_metrics_binary,
    args=TrainingArguments(
        output_dir="binary_output",
        num_train_epochs=4,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        learning_rate=1e-5,
        weight_decay=0.02,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        fp16=True,
        report_to="none"
    ),
)
trainer_binary.train()

# %%
trainer_fine = Trainer(
    model=fine_model,
    train_dataset=train_fine,
    eval_dataset=test_fine,
    compute_metrics=compute_metrics_fine,
    args=TrainingArguments(
        output_dir="fine_output_unweighted",
        num_train_epochs=4,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        learning_rate=1e-5,
        weight_decay=0.01,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        fp16=True,
        report_to="none"
    ),
)

trainer_fine.train()

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

def classify_two_stage(example):
    with torch.no_grad():
        logits = binary_model(**example).logits
    binary_pred = logits.argmax(dim=-1).item()

    if binary_pred == 1:
        return 2  # Clear Non-Reply

    with torch.no_grad():
        logits = fine_model(**example).logits
    fine_pred = logits.argmax(dim=-1).item()
    return fine_pred

def plot_cm(trainer, dataset, display_labels):
    predictions = trainer.predict(dataset)
    preds = np.argmax(predictions.predictions, axis=-1)
    labels = predictions.label_ids
    ConfusionMatrixDisplay.from_predictions(labels, preds, display_labels=display_labels)
    plt.show()

# %%
import os
from datetime import datetime
import json
import zipfile

os.environ["WANDB_DISABLED"] = "true"

class WeightedTrainer(Trainer):
    def __init__(self, weights=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.weights = weights

    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs["labels"]
        outputs = model(**inputs)
        logits = outputs.logits

        loss_fct = torch.nn.CrossEntropyLoss(weight=self.weights.to(model.device))
        loss = loss_fct(logits, labels)

        return (loss, outputs) if return_outputs else loss



trainer_binary = WeightedTrainer(
    weights=torch.tensor([1.0, 1.0]),
    model=binary_model,
    train_dataset=binary_train,
    eval_dataset=binary_test,
    compute_metrics=compute_metrics_binary,
    args=TrainingArguments(
        output_dir="binary_output",
        num_train_epochs=4,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        learning_rate=1e-5,
        weight_decay=0.01,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        fp16=True,
        report_to="none"
    ),
)
trainer_binary.train()

trainer_fine = Trainer(
    model=fine_model,
    train_dataset=train_fine,
    eval_dataset=test_fine,
    compute_metrics=compute_metrics_fine,
    args=TrainingArguments(
        output_dir="fine_output_unweighted",
        num_train_epochs=3,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        learning_rate=2e-5,
        weight_decay=0.01,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        fp16=True,
        report_to="none"
    ),
)

trainer_fine.train()

# ===== GENERIRANJE PREDIKCIJA ZA SUBMISSION =====

# Mapiranje indeksa u labele
label_mapping = {
    0: "Clear Reply",
    1: "Ambivalent",
    2: "Clear Non-Reply"
}

# Evaluacija dvostupanjskog sustava
binary_model.eval()
fine_model.eval()

test_examples = []
device = binary_model.device

for example in tokenized_test:
    model_input = {
        'input_ids': example['input_ids'].unsqueeze(0).to(device),
        'attention_mask': example['attention_mask'].unsqueeze(0).to(device)
    }
    test_examples.append(model_input)

# Dobij predikcije kroz dvostupanjski sustav
predictions = []
for example in test_examples:
    pred = classify_two_stage(example)
    predictions.append(pred)

# Pretvori indekse u labele
prediction_labels = [label_mapping[pred] for pred in predictions]

# Kreiraj direktorij za submission
submission_dir = "/content/submission"
os.makedirs(submission_dir, exist_ok=True)

# Spremi predikcije u fajl bez ekstenzije (samo "prediction")
prediction_file = os.path.join(submission_dir, "prediction")
with open(prediction_file, 'w') as f:
    for label in prediction_labels:
        f.write(f"{label}\n")

print(f"✓ Prediction file created: {prediction_file}")
print(f"  Total predictions: {len(prediction_labels)}")

# Kreiraj ZIP fajl
zip_path = "/content/submission.zip"
with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Dodaj samo fajl, bez foldera
    zipf.write(prediction_file, arcname="prediction")

print(f"\n✓ ZIP file created: {zip_path}")
print(f"\nPrvih 10 predikcija:")
for i, label in enumerate(prediction_labels[:10]):
    print(f"  {i+1}. {label}")

# Opciono: spremi i na Google Drive
from google.colab import drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

drive_zip_path = "/content/drive/MyDrive/submission.zip"
import shutil
shutil.copy(zip_path, drive_zip_path)
print(f"\n✓ ZIP file also saved to Google Drive: {drive_zip_path}")

# Provjeri strukturu ZIP fajla
print(f"\nZIP file contents:")
with zipfile.ZipFile(zip_path, 'r') as zipf:
    for name in zipf.namelist():
        print(f"  - {name}")

# %%
import os
from datetime import datetime
import json
import zipfile

os.environ["WANDB_DISABLED"] = "true"

class WeightedTrainer(Trainer):
    def __init__(self, weights=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.weights = weights

    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs["labels"]
        outputs = model(**inputs)
        logits = outputs.logits

        loss_fct = torch.nn.CrossEntropyLoss(weight=self.weights.to(model.device))
        loss = loss_fct(logits, labels)

        return (loss, outputs) if return_outputs else loss

results = {
    'macro_f1': [],
    'accuracy': [],
    'precision': [],
    'recall': []
}

for run in range(5):  # 5 pokretanja
    print(f"\n{'='*50}")
    print(f"RUN {run + 1}/5")
    print(f"{'='*50}\n")

    # Reinicijaliziraj modele
    binary_model = AutoModelForSequenceClassification.from_pretrained(
        "FacebookAI/roberta-base", num_labels=2
    )
    fine_model = AutoModelForSequenceClassification.from_pretrained(
        "FacebookAI/roberta-base", num_labels=2
    )

    # Train binary
    trainer_binary = WeightedTrainer(
        weights=torch.tensor([1.0, 1.0]),
        model=binary_model,
        train_dataset=binary_train,
        eval_dataset=binary_test,
        compute_metrics=compute_metrics_binary,
        args=TrainingArguments(
            output_dir=f"binary_output_run{run}",
            num_train_epochs=4,
            per_device_train_batch_size=16,
            per_device_eval_batch_size=16,
            learning_rate=1e-5,
            weight_decay=0.02,
            eval_strategy="epoch",
            save_strategy="epoch",
            load_best_model_at_end=True,
            metric_for_best_model="f1",
            fp16=True,
            report_to="none"
        ),
    )
    trainer_binary.train()

    # Train fine
    trainer_fine = Trainer(
        model=fine_model,
        train_dataset=train_fine,
        eval_dataset=test_fine,
        compute_metrics=compute_metrics_fine,
        args=TrainingArguments(
            output_dir=f"fine_output_run{run}",
            num_train_epochs=4,
            per_device_train_batch_size=16,
            per_device_eval_batch_size=16,
            learning_rate=1e-5,
            weight_decay=0.02,
            eval_strategy="epoch",
            save_strategy="epoch",
            load_best_model_at_end=True,
            metric_for_best_model="f1",
            fp16=True,
            report_to="none"
        ),
    )
    trainer_fine.train()

    # Evaluate dvostupanjski sustav
    binary_model.eval()
    fine_model.eval()

    test_examples = []
    true_labels = []

    device = binary_model.device

    for example in tokenized_test:
        model_input = {
            'input_ids': example['input_ids'].unsqueeze(0).to(device),
            'attention_mask': example['attention_mask'].unsqueeze(0).to(device)
        }
        test_examples.append(model_input)
        true_labels.append(example['label'].item())

    predictions = []
    for example in test_examples:
        pred = classify_two_stage(example)
        predictions.append(pred)

    # Izračunaj metrike
    from sklearn.metrics import accuracy_score

    macro_f1 = f1_score(true_labels, predictions, average='macro')
    accuracy = accuracy_score(true_labels, predictions)
    precision = precision_score(true_labels, predictions, average='macro', zero_division=0)
    recall = recall_score(true_labels, predictions, average='macro', zero_division=0)

    results['macro_f1'].append(macro_f1)
    results['accuracy'].append(accuracy)
    results['precision'].append(precision)
    results['recall'].append(recall)

    print(f"\n=== RUN {run + 1} RESULTS ===")
    print(classification_report(true_labels, predictions,
                              target_names=["Clear Reply", "Ambivalent", "Clear Non-Reply"]))
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print(f"F1 Score (macro): {macro_f1:.4f}")

# Finalni rezultati u formatu tablice
print(f"\n{'='*70}")
print(f"FINALNI REZULTATI ({len(results['macro_f1'])} pokretanja)")
print(f"{'='*70}")
print(f"{'Metric':<15} {'Min':<10} {'Max':<10} {'Avg ± Std':<25}")
print(f"{'-'*70}")

for metric_name, metric_values in results.items():
    min_val = np.min(metric_values)
    max_val = np.max(metric_values)
    avg_val = np.mean(metric_values)
    std_val = np.std(metric_values)

    # Formatiranje naziva metrike
    display_name = metric_name.replace('_', ' ').title()
    if metric_name == 'macro_f1':
        display_name = 'F1 Score'

    print(f"{display_name:<15} {min_val:<10.4f} {max_val:<10.4f} {avg_val:.4f} ± {std_val:.4f}")

print(f"{'='*70}")
